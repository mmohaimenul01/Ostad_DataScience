# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(11)
y1 = x + 2
y2 = x + 3
plt.plot(x, y1, label='x+2', color='blue')
plt.plot(x, y2, label='x+3', color='orange')
plt.legend(loc='lower right')
plt.show()
